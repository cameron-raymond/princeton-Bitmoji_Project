# %% [markdown]
# # Bitmoji Parser
#
# ### Flow
# **For each image**:
# 1. Find all of the green rectanges (HSV between (40,150,210) and (120,250,250))
# 2. Save each green rectangle – with an area greater than 1000 pixels, and a height and width each greater than 40 pixels – to a new image. These represent XXX category of images and are saved with the naming convention "\[original name\]-XXX_category-\[object number\].png"
# 3. Repeat for other colour rectangles too

# %%
from matplotlib import pyplot as plt
from glob import glob
import random as rng
import pandas as pd
import numpy as np
import cv2

INPUT_FOLDER = glob("../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/*")
OUTPUT_FOLDER = "../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments"

# %%
import os

def find_bounding_boxes(hsv_img,
                        colour_dict):
    """
    
        Returns an array of bounding boxes
    """
    low,high = colour_dict['low_hsv'], colour_dict['high_hsv']
    mask = cv2.inRange(hsv_img, low, high)
    masked_img = cv2.bitwise_and(hsv_img, hsv_img, mask = mask)
    # Converting the image to grayscale helps with the findContours function
    masked_grey = cv2.cvtColor(masked_img, cv2.COLOR_BGR2GRAY)
    # Smoothing without removing edges.
    bi_lat = cv2.bilateralFilter(masked_grey, 7, 50, 50)
    # Adding a bit of blur and then thresholding helps reduce noise
    blurred = cv2.blur(bi_lat, (3,3))
    #Apply thresholding to the image
    ret, thresholded = cv2.threshold(blurred, 1, 255, cv2.THRESH_OTSU)
    contours, hierarchy = cv2.findContours(thresholded,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
    bounding_boxes = [cv2.boundingRect(c) for c in contours]
    return bounding_boxes


def write_bounding_boxes(img,
                         bounding_boxes,
                         img_prefix = "../data/output/[image_name]-[category]",
                         offset = 0,
                         thresh = lambda x,y,w,h : h*w*1000 and w > 40 and h > 40):
    # filter out noise based on preset threshold
    bounding_boxes = [bb for bb in bounding_boxes if thresh(*bb)]
    object_ids = []
    for i,[x,y,w,h] in enumerate(bounding_boxes):
        section = img[y:y+h, x:x+w]
        obj_id = i+offset
        object_ids.append(obj_id)
        cv2.imwrite(f"{img_prefix}-{obj_id:03d}.png", section[:,:,::-1])
    return bounding_boxes,object_ids


def output_path(img_fp,colour_dict):
    direc = OUTPUT_FOLDER
    # Get rid of whatever is after the last period
    img_pref = os.path.basename(img_fp).split('.')[0]
    category = colour_dict['category']
    return img_pref, f"{direc}/{img_pref}_{category}"

# %% [markdown]
# ## Parse bounding boxes

# %%
from utils import categories

series = []
for path  in INPUT_FOLDER:
    offset = 0
    for colour in categories:
        img_name, output_prefix = output_path(path,colour)
        bitmoji = cv2.imread(path, 1)
        bitmoji = cv2.cvtColor(bitmoji, cv2.COLOR_BGR2RGB)
        hsv_bitmoji = cv2.cvtColor(bitmoji, cv2.COLOR_RGB2HSV)
        bounding_boxes = find_bounding_boxes(hsv_bitmoji,colour)
        bef = len(bounding_boxes)
        bounding_boxes,object_ids = write_bounding_boxes(bitmoji,
                                              bounding_boxes,
                                              output_prefix,
                                              offset)
        offset += len(bounding_boxes)
        for [x,y,w,h],obj_id in zip(bounding_boxes,object_ids):
            row = [img_name, # image name
                   colour['category'], #category
                   obj_id,
                   x, #X1
                   x+w, #X2
                   y, #Y1
                   y+h #Y2
                  ]
            series.append(row)
        if len(bounding_boxes): print(path,output_prefix,bef,'->',len(bounding_boxes))

coordinate_df = pd.DataFrame(series,columns=["Image Name",
                                             "Object Category",
                                             "Object ID",
                                             "X1 Coordinate",
                                             "X2 Coordinate",
                                             "Y1 Coordinate",
                                             "Y2 Coordinate"]).sort_values(["Image Name","Object ID"])

print("{} rows and {} columns".format(*coordinate_df.shape))
# Out:
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user26_2195.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user26_2195_02_wall_hangings 1 -> 1
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user38_4029.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user38_4029_01_books 11 -> 1
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user38_4029.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user38_4029_02_wall_hangings 140 -> 4
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user42_4681 copy.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user42_4681 copy_01_books 35 -> 4
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user58_998 copy.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user58_998 copy_03_objects 2 -> 2
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user18_2193.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user18_2193_02_wall_hangings 21 -> 6
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user58_998.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user58_998_02_wall_hangings 99 -> 16
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user58_998.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user58_998_03_objects 2 -> 2
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user12_4668.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user12_4668_02_wall_hangings 3 -> 3
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user12_4668.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user12_4668_03_objects 1 -> 1
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user43_242.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user43_242_02_wall_hangings 50 -> 10
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user21_217 2.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user21_217 2_01_books 6 -> 3
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user21_217 2.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user21_217 2_02_wall_hangings 3 -> 2
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user21_217 2.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user21_217 2_03_objects 2 -> 2
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user67_4063 copy.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user67_4063 copy_03_objects 34 -> 5
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user54_4688.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user54_4688_02_wall_hangings 5 -> 1
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user54_4688.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user54_4688_03_objects 2 -> 2
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user9_3238.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user9_3238_01_books 3 -> 3
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user9_3238.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user9_3238_02_wall_hangings 4 -> 2
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user9_3238.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user9_3238_03_objects 3 -> 3
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user32_2809.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user32_2809_01_books 1 -> 1
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user32_2809.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user32_2809_02_wall_hangings 77 -> 6
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user32_2809.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user32_2809_03_objects 32 -> 7
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user9_4519.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user9_4519_01_books 6 -> 4
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user9_4519.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user9_4519_02_wall_hangings 38 -> 1
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user9_4519.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user9_4519_03_objects 5 -> 2
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user34_981.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user34_981_02_wall_hangings 27 -> 3
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user34_981.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user34_981_03_objects 10 -> 3
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user57_2224.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user57_2224_01_books 1 -> 1
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user57_2224.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user57_2224_02_wall_hangings 7 -> 2
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user57_2224.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user57_2224_03_objects 60 -> 2
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user50_251.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user50_251_01_books 12 -> 12
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user50_251.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user50_251_02_wall_hangings 19 -> 2
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user67_4063.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user67_4063_02_wall_hangings 67 -> 1
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user67_4063.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user67_4063_03_objects 92 -> 7
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user27_4026.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user27_4026_02_wall_hangings 12 -> 1
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user27_4026.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user27_4026_03_objects 57 -> 1
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user43_242 copy.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user43_242 copy_03_objects 1 -> 1
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user11_106.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user11_106_01_books 30 -> 13
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user11_106.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user11_106_02_wall_hangings 4 -> 2
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user11_106.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user11_106_03_objects 5 -> 5
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user9_4520.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user9_4520_02_wall_hangings 27 -> 3
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user9_4520.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user9_4520_03_objects 7 -> 1
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user38_4029 copy.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user38_4029 copy_01_books 3 -> 2
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user38_4029 copy.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user38_4029 copy_03_objects 13 -> 1
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user62_2825 copy.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user62_2825 copy_02_wall_hangings 15 -> 2
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user53_3476.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user53_3476_02_wall_hangings 19 -> 2
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user53_3476.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user53_3476_03_objects 3 -> 3
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user62_2825.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user62_2825_02_wall_hangings 31 -> 5
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user62_2825.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user62_2825_03_objects 2 -> 1
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user45_2221.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user45_2221_02_wall_hangings 1 -> 1
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user45_2221.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user45_2221_03_objects 4 -> 1
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user34_231.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user34_231_01_books 1 -> 1
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user34_231.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user34_231_02_wall_hangings 31 -> 3
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user10_4547 2.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user10_4547 2_01_books 11 -> 1
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user21_217.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user21_217_01_books 47 -> 14
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user21_217.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user21_217_02_wall_hangings 7 -> 5
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user21_217.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user21_217_03_objects 2 -> 2
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user50_251 copy.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user50_251 copy_01_books 8 -> 8
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user17_1570.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user17_1570_02_wall_hangings 3 -> 1
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user17_1570.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user17_1570_03_objects 8 -> 3
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user37_235.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user37_235_02_wall_hangings 4 -> 1
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user37_235.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user37_235_03_objects 7 -> 1
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user16_2800.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user16_2800_02_wall_hangings 3 -> 1
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user31_2198.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user31_2198_02_wall_hangings 25 -> 3
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user31_2198.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user31_2198_03_objects 6 -> 1
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user16_2800 2.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user16_2800 2_02_wall_hangings 51 -> 8
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user16_2800 2.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user16_2800 2_03_objects 13 -> 12
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user64_3484.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user64_3484_02_wall_hangings 14 -> 2
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user31_2199.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user31_2199_03_objects 17 -> 1
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user37_236.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user37_236_02_wall_hangings 11 -> 2
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user37_236.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user37_236_03_objects 12 -> 1
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user42_4681.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user42_4681_01_books 37 -> 4
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user42_4681.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user42_4681_02_wall_hangings 16 -> 4
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user42_4681.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user42_4681_03_objects 2 -> 2
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user42_4681.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user42_4681_04_teacher 1 -> 1
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user31_2200.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user31_2200_02_wall_hangings 41 -> 6
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user46_244 copy.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user46_244 copy_01_books 2 -> 2
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user46_245.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user46_245_01_books 4 -> 4
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user46_245.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user46_245_02_wall_hangings 26 -> 6
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user46_245.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user46_245_03_objects 4 -> 2
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user10_4547.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user10_4547_01_books 20 -> 3
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user10_4547.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user10_4547_02_wall_hangings 58 -> 4
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user46_244.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user46_244_01_books 4 -> 4
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user46_244.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user46_244_02_wall_hangings 29 -> 5
# ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Item Tagging/Kaytee/Tagged/user46_244.jpg ../../../../../Dropbox (Princeton)/BitmojiClassroomTwitter/Parsed Image Segments/user46_244_03_objects 2 -> 2
# 292 rows and 7 columns

# %%
coordinate_df.to_csv("../data/coordinates.csv",index=False)
