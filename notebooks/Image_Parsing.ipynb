# %% [markdown]
# # Image parsing
#
# For each image, parse out each bounding box into a new image, use different naming conventions/folders for different coloured box

# %%
from matplotlib import pyplot as plt
import random as rng
import pandas as pd
import numpy as np
import cv2

path='../data/EvrSPGZUUAIV6Yv.jpg'
img = cv2.imread(path, 1)
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
blurred = cv2.GaussianBlur(gray, (3, 3), 0)
canny = cv2.Canny(blurred, 120, 255, 1)
plt.imshow(canny)

# %%
# Find contours
cnts = cv2.findContours(img, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
cnts = cnts[0] if len(cnts) == 2 else cnts[1]

# Iterate thorugh contours and draw rectangles around contours
for c in cnts:
    x,y,w,h = cv2.boundingRect(c)
    cv2.rectangle(img, (x, y), (x + w, y + h), (36,255,12), 2)
    
plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-12-bec3c24edd5d> in <module>
#       1 # Find contours
# ----> 2 cnts = cv2.findContours(img, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
#       3 cnts = cnts[0] if len(cnts) == 2 else cnts[1]
#       4
#       5 # Iterate thorugh contours and draw rectangles around contours
#
# error: OpenCV(4.5.2) /private/var/folders/24/8k48jl6d249_n_qfxwsl6xvm0000gn/T/pip-req-build-v0gme71y/opencv/modules/imgproc/src/contours.cpp:197: error: (-210:Unsupported format or combination of formats) [Start]FindContours supports only CV_8UC1 images when mode != CV_RETR_FLOODFILL otherwise supports CV_32SC1 images only in function 'cvStartFindContours_Impl'
